# %% [markdown]
# <a href="https://colab.research.google.com/github/gandepallichandini2003/GANDEPALLI-CHANDINI/blob/main/DATA_VISUALIZATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Load Dataset

# %%
file_name = list(uploaded.keys())[0]
df = pd.read_excel(file_name)

# %% [markdown]
# View Data

# %%
df.head()
# Out:
#    Patient_ID  Age  Gender      Condition                 Procedure   Cost  \
# 0           1   45  Female  Heart Disease               Angioplasty  15000
# 1           2   60    Male       Diabetes           Insulin Therapy   2000
# 2           3   32  Female  Fractured Arm          X-Ray and Splint    500
# 3           4   75    Male         Stroke    CT Scan and Medication  10000
# 4           5   50  Female         Cancer  Surgery and Chemotherapy  25000
#
#    Length_of_Stay Readmission    Outcome  Satisfaction
# 0               5          No  Recovered             4
# 1               3         Yes     Stable             3
# 2               1          No  Recovered             5
# 3               7         Yes     Stable             2
# 4              10          No  Recovered             4

# %% [markdown]
# Bar Chart

# %%
df['Gender'].value_counts().plot(kind='bar')
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Pie Chart

# %%
df['Condition'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Condition Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# Histogram

# %%
plt.hist(df['Age'])
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Scatter Plot

# %%
plt.scatter(df['Age'], df['Cost'])
plt.xlabel("Age")
plt.ylabel("Cost")
plt.title("Age vs Cost")
plt.show()
